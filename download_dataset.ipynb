# %%
from datasets import load_dataset

# %%
traindata = load_dataset(
    'allenai/c4', data_files={'train': 'en/c4-train.00000-of-01024.json.gz'}, split='train'
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 traindata = load_dataset(
#       2     '/root/.cache/huggingface/datasets/allenai___c4', data_files={'train': 'en/c4-train.00000-of-01024.json.gz'}, split='train'
#       3 )
#
# File ~/anaconda3/envs/atom/lib/python3.10/site-packages/datasets/load.py:2129, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, ignore_verifications, keep_in_memory, save_infos, revision, token, use_auth_token, task, streaming, num_proc, storage_options, **config_kwargs)
#    2124 verification_mode = VerificationMode(
#    2125     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2126 )
#    2128 # Create a dataset builder
# -> 2129 builder_instance = load_dataset_builder(
#    2130     path=path,
#    2131     name=name,
#    2132     data_dir=data_dir,
#    2133     data_files=data_files,
#    2134     cache_dir=cache_dir,
#    2135     features=features,
#    2136     download_config=download_config,
#    2137     download_mode=download_mode,
#    2138     revision=revision,
#    2139     token=token,
#    2140     storage_options=storage_options,
#    2141     **config_kwargs,
#    2142 )
#    2144 # Return iterable dataset in case of streaming
#    2145 if streaming:
#
# File ~/anaconda3/envs/atom/lib/python3.10/site-packages/datasets/load.py:1815, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, use_auth_token, storage_options, **config_kwargs)
#    1813     download_config = download_config.copy() if download_config else DownloadConfig()
#    1814     download_config.storage_options.update(storage_options)
# -> 1815 dataset_module = dataset_module_factory(
#    1816     path,
#    1817     revision=revision,
#    1818     download_config=download_config,
#    1819     download_mode=download_mode,
#    1820     data_dir=data_dir,
#    1821     data_files=data_files,
#    1822 )
#    1823 # Get dataset builder class from the processing script
#    1824 builder_kwargs = dataset_module.builder_kwargs
#
# File ~/anaconda3/envs/atom/lib/python3.10/site-packages/datasets/load.py:1446, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, **download_kwargs)
#    1440     return LocalDatasetModuleFactoryWithScript(
#    1441         combined_path, download_mode=download_mode, dynamic_modules_path=dynamic_modules_path
#    1442     ).get_module()
#    1443 elif os.path.isdir(path):
#    1444     return LocalDatasetModuleFactoryWithoutScript(
#    1445         path, data_dir=data_dir, data_files=data_files, download_mode=download_mode
# -> 1446     ).get_module()
#    1447 # Try remotely
#    1448 elif is_relative_path(path) and path.count("/") <= 1:
#
# File ~/anaconda3/envs/atom/lib/python3.10/site-packages/datasets/load.py:860, in LocalDatasetModuleFactoryWithoutScript.get_module(self)
#     858 else:
#     859     patterns = get_data_patterns(base_path)
# --> 860 data_files = DataFilesDict.from_patterns(
#     861     patterns,
#     862     base_path=base_path,
#     863     allowed_extensions=ALL_ALLOWED_EXTENSIONS,
#     864 )
#     865 module_name, default_builder_kwargs = infer_module_for_data_files(
#     866     data_files=data_files,
#     867     path=self.path,
#     868 )
#     869 data_files = data_files.filter_extensions(_MODULE_TO_EXTENSIONS[module_name])
#
# File ~/anaconda3/envs/atom/lib/python3.10/site-packages/datasets/data_files.py:686, in DataFilesDict.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     683 out = cls()
#     684 for key, patterns_for_key in patterns.items():
#     685     out[key] = (
# --> 686         DataFilesList.from_patterns(
#     687             patterns_for_key,
#     688             base_path=base_path,
#     689             allowed_extensions=allowed_extensions,
#     690             download_config=download_config,
#     691         )
#     692         if not isinstance(patterns_for_key, DataFilesList)
#     693         else patterns_for_key
#     694     )
#     695 return out
#
# File ~/anaconda3/envs/atom/lib/python3.10/site-packages/datasets/data_files.py:591, in DataFilesList.from_patterns(cls, patterns, base_path, allowed_extensions, download_config)
#     588 for pattern in patterns:
#     589     try:
#     590         data_files.extend(
# --> 591             resolve_pattern(
#     592                 pattern,
#     593                 base_path=base_path,
#     594                 allowed_extensions=allowed_extensions,
#     595                 download_config=download_config,
#     596             )
#     597         )
#     598     except FileNotFoundError:
#     599         if not has_magic(pattern):
#
# File ~/anaconda3/envs/atom/lib/python3.10/site-packages/datasets/data_files.py:380, in resolve_pattern(pattern, base_path, allowed_extensions, download_config)
#     378     if allowed_extensions is not None:
#     379         error_msg += f" with any supported extension {list(allowed_extensions)}"
# --> 380     raise FileNotFoundError(error_msg)
#     381 return out
#
# FileNotFoundError: Unable to find '/root/.cache/huggingface/datasets/allenai___c4/en/c4-train.00000-of-01024.json.gz' with any supported extension ['.csv', '.tsv', '.json', '.jsonl', '.parquet', '.arrow', '.txt', '.blp', '.bmp', '.dib', '.bufr', '.cur', '.pcx', '.dcx', '.dds', '.ps', '.eps', '.fit', '.fits', '.fli', '.flc', '.ftc', '.ftu', '.gbr', '.gif', '.grib', '.h5', '.hdf', '.png', '.apng', '.jp2', '.j2k', '.jpc', '.jpf', '.jpx', '.j2c', '.icns', '.ico', '.im', '.iim', '.tif', '.tiff', '.jfif', '.jpe', '.jpg', '.jpeg', '.mpg', '.mpeg', '.msp', '.pcd', '.pxr', '.pbm', '.pgm', '.ppm', '.pnm', '.psd', '.bw', '.rgb', '.rgba', '.sgi', '.ras', '.tga', '.icb', '.vda', '.vst', '.webp', '.wmf', '.emf', '.xbm', '.xpm', '.BLP', '.BMP', '.DIB', '.BUFR', '.CUR', '.PCX', '.DCX', '.DDS', '.PS', '.EPS', '.FIT', '.FITS', '.FLI', '.FLC', '.FTC', '.FTU', '.GBR', '.GIF', '.GRIB', '.H5', '.HDF', '.PNG', '.APNG', '.JP2', '.J2K', '.JPC', '.JPF', '.JPX', '.J2C', '.ICNS', '.ICO', '.IM', '.IIM', '.TIF', '.TIFF', '.JFIF', '.JPE', '.JPG', '.JPEG', '.MPG', '.MPEG', '.MSP', '.PCD', '.PXR', '.PBM', '.PGM', '.PPM', '.PNM', '.PSD', '.BW', '.RGB', '.RGBA', '.SGI', '.RAS', '.TGA', '.ICB', '.VDA', '.VST', '.WEBP', '.WMF', '.EMF', '.XBM', '.XPM', '.aiff', '.au', '.avr', '.caf', '.flac', '.htk', '.svx', '.mat4', '.mat5', '.mpc2k', '.ogg', '.paf', '.pvf', '.raw', '.rf64', '.sd2', '.sds', '.ircam', '.voc', '.w64', '.wav', '.nist', '.wavex', '.wve', '.xi', '.mp3', '.opus', '.AIFF', '.AU', '.AVR', '.CAF', '.FLAC', '.HTK', '.SVX', '.MAT4', '.MAT5', '.MPC2K', '.OGG', '.PAF', '.PVF', '.RAW', '.RF64', '.SD2', '.SDS', '.IRCAM', '.VOC', '.W64', '.WAV', '.NIST', '.WAVEX', '.WVE', '.XI', '.MP3', '.OPUS', '.zip']

# %%
valdata = load_dataset(
    'allenai/c4', data_files={'validation': 'en/c4-validation.00000-of-00008.json.gz'}, split='validation'
)

# %%
traindata = load_dataset('ptb_text_only', 'penn_treebank', split='train')
testdata = load_dataset('ptb_text_only', 'penn_treebank', split='test')
